# %%
import os
import sys

print(f"Python version: {sys.version}")
print(f"Current working directory: {os.getcwd()}")
# Out:
# Python version: 3.13.7 (main, Sep 13 2025, 17:38:53) [GCC 12.2.0]
# Current working directory: /home/lukasz/Documents/code/py/ml/notebooks

# %%
import sys
import os

# 1. Add 'src' to the path so Python can find your script
sys.path.append(os.path.abspath('../src'))

# 2. Import your custom function
from data_loader import load_and_clean_data

# 3. Use it
df = load_and_clean_data("iris.csv")
print(df.head())
# Out:
# --- Loading data from: /home/lukasz/Documents/code/py/ml/src/../data/raw/iris.csv ---
# Removed 1 duplicate rows.
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
